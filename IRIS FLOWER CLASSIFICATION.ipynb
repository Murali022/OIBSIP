# %% [markdown]
# <a href="https://colab.research.google.com/github/Murali022/OIBSIP/blob/main/IRIS%20FLOWER%20CLASSIFICATION.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Import Necessary Libraries**

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("/content/Iris.csv")

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.shape
# Out:
# (150, 6)

# %% [markdown]
# **Dropping the Column**

# %%
df=df.drop(columns=["Id"])

# %%
df.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# **Transforming Categorical Data into Numeric Data**

# %%
df["Species"].replace({"Iris-setosa":1, "Iris-setosa":2, "Iris-setosa":3},inplace = True)

# %%
df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2               3
# 1              4.9           3.0            1.4           0.2               3
# 2              4.7           3.2            1.3           0.2               3
# 3              4.6           3.1            1.5           0.2               3
# 4              5.0           3.6            1.4           0.2               3
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# **Creating Arrays**

# %%
x=pd.DataFrame(df,columns=["SeplLengthCm","SeplWidthCm","PetalLengthCm","PetalWidthCm"]).values

# %%
x
# Out:
# array([[nan, nan, 1.4, 0.2],
#        [nan, nan, 1.4, 0.2],
#        [nan, nan, 1.3, 0.2],
#        [nan, nan, 1.5, 0.2],
#        [nan, nan, 1.4, 0.2],
#        [nan, nan, 1.7, 0.4],
#        [nan, nan, 1.4, 0.3],
#        [nan, nan, 1.5, 0.2],
#        [nan, nan, 1.4, 0.2],
#        [nan, nan, 1.5, 0.1],
#        [nan, nan, 1.5, 0.2],
#        [nan, nan, 1.6, 0.2],
#        [nan, nan, 1.4, 0.1],
#        [nan, nan, 1.1, 0.1],
#        [nan, nan, 1.2, 0.2],
#        [nan, nan, 1.5, 0.4],
#        [nan, nan, 1.3, 0.4],
#        [nan, nan, 1.4, 0.3],
#        [nan, nan, 1.7, 0.3],
#        [nan, nan, 1.5, 0.3],
#        [nan, nan, 1.7, 0.2],
#        [nan, nan, 1.5, 0.4],
#        [nan, nan, 1. , 0.2],
#        [nan, nan, 1.7, 0.5],
#        [nan, nan, 1.9, 0.2],
#        [nan, nan, 1.6, 0.2],
#        [nan, nan, 1.6, 0.4],
#        [nan, nan, 1.5, 0.2],
#        [nan, nan, 1.4, 0.2],
#        [nan, nan, 1.6, 0.2],
#        [nan, nan, 1.6, 0.2],
#        [nan, nan, 1.5, 0.4],
# ...

# %%
y = df.Species.values.reshape(-1,1)

# %%
y
# Out:
# array([[3],
#        [3],
#        [3],
#        [3],
#        [3],
#        [3],
#        [3],
#        [3],
#        [3],
#        [3],
#        [3],
#        [3],
#        [3],
#        [3],
#        [3],
#        [3],
#        [3],
#        [3],
#        [3],
#        [3],
#        [3],
#        [3],
#        [3],
#        [3],
#        [3],
#        [3],
#        [3],
#        [3],
#        [3],
#        [3],
#        [3],
#        [3],
#        [3],
#        [3],
#        [3],
#        [3],
#        [3],
#        [3],
#        [3],
#        [3],
#        [3],
#        [3],
#        [3],
#        [3],
#        [3],
#        [3],
#        [3],
#        [3],
#        [3],
#        [3],
#        ['Iris-versicolor'],
#        ['Iris-versicolor'],
#        ['Iris-versicolor'],
#        ['Iris-versicolor'],
#        ['Iris-versicolor'],
#        ['Iris-versicolor'],
#        ['Iris-versicolor'],
#        ['Iris-versicolor'],
#        ['Iris-versicolor'],
#        ['Iris-versicolor'],
# ...

# %% [markdown]
# **Import Necessary Libraries**

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn import metrics

# %% [markdown]
# **Train Test Split**

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.30, random_state=42)

# %%
x_train.shape
# Out:
# (105, 4)

# %%
y_train.shape
# Out:
# (105, 1)

# %%
k=6
knclr=KNeighborsClassifier(k)
